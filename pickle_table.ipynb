# %%
import os
import pickle
import re
import boto3
import pandas as pd
from botocore import UNSIGNED
from botocore.config import Config
DATADIR = '/ocean/projects/med220004p/shared/data_sandbox/derived/RBC-testing/data/UPenn'


def fieldmap_type(path):
    if 'fmap' not in os.listdir(path):
        return 'None'
    else:
        fmaps = os.listdir(os.path.join(path, 'fmap'))
        if not fmaps:
            return 'None'
        elif any(fmap.endswith('_phase1.nii.gz') or fmap.endswith('_phasediff.nii.gz') for fmap in fmaps):
            return 'phasediff'
        elif any(fmap.endswith('_epi.nii.gz') for fmap in fmaps):
            return 'epi'
    return 'unknown'


def key_from_s3(key):
    _subses = [x_for_session(key, x) for x in ('task', 'run', 'acq') if
               f'_{x}-' in key]
    _key = '_'.join([part for part in [*key.split('/', 2)[:2], *_subses] if
                     part is not None])
    return _key


def match_all_entities(filepath, key, minimal=False):
    entities = key.split('_')
    if minimal:
        entities = [entity for entity in entities if
                    any(entity.startswith(minkey) for minkey in ('sub-', 'ses-'))]
    if all(entity in filepath for entity in entities):
        return True
    return False


def x_for_session(filename, x):
    return f"{x}-{re.search(f'(?<=_{x}-)[0-9a-zA-Z]*(?=_)', filename).group(0)}"

# %%
# Create and pickle raw data DataFrame
# local raw data
runs = {}
for dataset in [dataset for dataset in os.listdir(DATADIR) if dataset != 'HBN']:
    datasetdir = os.path.join(DATADIR, dataset)
    for subject in os.listdir(datasetdir):
        subdir = os.path.join(datasetdir, subject)
        if os.path.isdir(subdir):
            for ses in os.listdir(subdir):
                sesdir = os.path.join(subdir, ses)
                sestask = None
                sesrun = None
                for typedir in os.listdir(sesdir):
                    for _file in os.listdir(os.path.join(sesdir, typedir)):
                        _key = f'{subject}_{ses}'
                        _subses = [x_for_session(_file, x) for x in ('task', 'run', 'acq') if
                                   f'_{x}-' in _file]
                        if _subses:
                            _key = '_'.join([_key, *_subses])
                            runs.update({_key: {'dataset': dataset, 'path': os.path.join(subdir, ses)}})
                if sestask is None and sesrun is None:
                    runs.update({f'{subject}_{ses}': {'dataset': dataset, 'path': os.path.join(subdir, ses)}})
for run in list(runs.keys()):
    if any([_run != run and _run.startswith(run) for _run in runs]):
        del runs[run]
    else:
        for subdir in ['anat', 'func']:
            subpath = os.path.join(runs[run]['path'], subdir)
            runs[run][subdir] = os.path.exists(subpath) and bool(os.listdir(subpath))
df = pd.DataFrame(runs).T
df[(df['anat'] == True) & (df['func'] == True)]
df['fieldmaps'] = df['path'].apply(fieldmap_type)

# %%
# S3 raw data
client = boto3.client('s3', config=Config(signature_version=UNSIGNED))
hbn_files = []
hbn_run_table = {}
with open(f'{DATADIR}/HBN/HBN_subs.txt', 'r', encoding='utf-8') as _f:
    hbn_subs = [sub.strip() for sub in _f.readlines()]
keep_getting = True
nct = None
while keep_getting:
    if nct is None:
        hbn_next = client.list_objects_v2(Bucket='fcp-indi', Prefix='data/Projects/HBN/BIDS_datalad/')
    else:
        hbn_next = client.list_objects_v2(Bucket='fcp-indi', Prefix='data/Projects/HBN/BIDS_datalad/',
                                          ContinuationToken=nct)
    hbn_files += [key for key in [
        re.sub('^data/Projects/HBN/BIDS_datalad/', '', key.get('Key', '')) for key in hbn_next['Contents']
    ] if any(key.startswith(sub) for sub in hbn_subs)]
    nct = hbn_next.get('NextContinuationToken')
    keep_getting = hbn_next.get('IsTruncated')
_hbn_runs = list(set(key_from_s3(key) for key in hbn_files))
hbn_runs = []
for run in _hbn_runs:
    if not any([_run != run and _run.startswith(run) for _run in _hbn_runs]):
        hbn_runs.append(run)
for key in hbn_runs:
    hbn_run_table[key] = {'path': 's3://fcp-indi/data/Projects/HBN/BIDS_datalad/' + 
                          '/'.join(key.split('_', 2)[:2]), 'dataset': 'HBN',
                          'anat': False, 'func': False, 'fieldmaps': 'None'}
for _file in hbn_files:
    for subdir in ['anat', 'func']:
        if f'/{subdir}/' in _file and not _file.endswith(f'/{subdir}/'):
            s3key = key_from_s3(_file)
            if subdir == 'anat':
                for _key in list(hbn_run_table.keys()):
                    if match_all_entities(_file, _key, minimal=True):
                        hbn_run_table[_key][subdir] = True
            else:
                hbn_run_table[s3key][subdir] = True
    if 'fmap' in _file:
        s3key = key_from_s3(_file)
        if _file.endswith('_phasediff.nii.gz') or _file.endswith('_phase1.nii.gz'):
            for _key in list(hbn_run_table.keys()):
                if match_all_entities(_file, _key, minimal=True):
                    hbn_run_table[_key]['fieldmaps'] = 'phasediff'
        if _file.endswith('_epi.nii.gz'):
            for _key in list(hbn_run_table.keys()):
                if match_all_entities(_file, _key, minimal=True):
                    hbn_run_table[_key]['fieldmaps'] = 'epi'
hbn_df = pd.DataFrame(hbn_run_table).T
# join local & s3 tables
df = pd.concat([df, hbn_df])
# drop runs missing anatomical or functional data
df = df[(df['anat'] == True) & (df['func'] == True)]
for col in ('anat', 'func'):
    df.drop(col, axis='columns', inplace=True)
# save picke and TSV
df.index.rename('subject_session', inplace=True)
with open('raw_data.🥒', 'wb') as _f:
    pickle.dump(df, _f)
df.to_csv('raw_data.tsv', sep='\t')

# %%
# Load pickled dataframe
with open('raw_data.🥒', 'rb') as _f:
    df = pickle.load(_f)
len(df)
# Out:
# 4168

# %%
CONNECTOME_DIRECTORY = ('/ocean/projects/med220004p/shared/data_sandbox/derived/RBC-testing/'
                        'runs/generated_connectomes')
df['connectome: fMRIPrep'] = ''
df['connectome: C-PAC: fmriprep-options'] = ''
for run in list(df.index):
    for connectome in os.listdir(os.path.join(CONNECTOME_DIRECTORY, 'Fmriprep')):
        if match_all_entities(connectome, run):
            df.loc[run]['connectome: fMRIPrep'] = connectome
    for connectome in os.listdir(os.path.join(CONNECTOME_DIRECTORY, 'CpacFmriprepOptions')):
        if match_all_entities(connectome, run):
            df.loc[run]['connectome: C-PAC: fmriprep-options'] = connectome
# update pickle and TSV
with open('raw_data.🥒', 'wb') as _f:
    pickle.dump(df, _f)
df.to_csv('raw_data.tsv', sep='\t')

# %%
# all runs
df
# Out:
#                                                    dataset  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity            NKI
# sub-A00085406_ses-BAS1_task-rest_acq-1400              NKI
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400      NKI
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400        NKI
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645       NKI
# ...                                                    ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1         HBN
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1       HBN
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2         HBN
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...     HBN
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP            HBN
#
#                                                                                                  path  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity         /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-rest_acq-1400           /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400   /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400     /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645    /ocean/projects/med220004p/shared/data_sandbox...
# ...                                                                                               ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1      s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1    s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2      s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP         s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                    fieldmaps  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity             None
# sub-A00085406_ses-BAS1_task-rest_acq-1400               None
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400       None
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400         None
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645        None
# ...                                                      ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1           epi
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1         epi
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2           epi
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...       epi
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP              epi
#
#                                                                                  connectome: fMRIPrep  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity
# sub-A00085406_ses-BAS1_task-rest_acq-1400           sub-A00085406_ses-BAS1_task-rest_acq-1400_spac...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400   sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1...
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400     sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-140...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645    sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-6...
# ...                                                                                               ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2      sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2...
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP
#
#                                                    connectome: C-PAC: fmriprep-options
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity
# sub-A00085406_ses-BAS1_task-rest_acq-1400
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645
# ...                                                                                ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP
#
# [4168 rows x 5 columns]

# %%
# all runs without fieldmaps
df[(df['fieldmaps'] == 'None')]
# Out:
#                                                    dataset  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity            NKI
# sub-A00085406_ses-BAS1_task-rest_acq-1400              NKI
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400      NKI
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400        NKI
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645       NKI
# ...                                                    ...
# sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_run-1_...     HBN
# sub-NDARVU683CTN_ses-HBNsiteRU_task-peer_run-1_...     HBN
# sub-NDARGX443CEU_ses-HBNsiteRU_task-rest_run-2_...     HBN
# sub-NDARGF367KVL_ses-HBNsiteRU_task-rest_run-1_...     HBN
# sub-NDARDF568GL5_ses-HBNsiteRU_task-peer_run-2_...     HBN
#
#                                                                                                  path  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity         /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-rest_acq-1400           /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400   /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400     /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645    /ocean/projects/med220004p/shared/data_sandbox...
# ...                                                                                               ...
# sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_run-1_...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARVU683CTN_ses-HBNsiteRU_task-peer_run-1_...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARGX443CEU_ses-HBNsiteRU_task-rest_run-2_...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARGF367KVL_ses-HBNsiteRU_task-rest_run-1_...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARDF568GL5_ses-HBNsiteRU_task-peer_run-2_...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                    fieldmaps  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity             None
# sub-A00085406_ses-BAS1_task-rest_acq-1400               None
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400       None
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400         None
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645        None
# ...                                                      ...
# sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_run-1_...      None
# sub-NDARVU683CTN_ses-HBNsiteRU_task-peer_run-1_...      None
# sub-NDARGX443CEU_ses-HBNsiteRU_task-rest_run-2_...      None
# sub-NDARGF367KVL_ses-HBNsiteRU_task-rest_run-1_...      None
# sub-NDARDF568GL5_ses-HBNsiteRU_task-peer_run-2_...      None
#
#                                                                                  connectome: fMRIPrep  \
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity
# sub-A00085406_ses-BAS1_task-rest_acq-1400           sub-A00085406_ses-BAS1_task-rest_acq-1400_spac...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400   sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1...
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400     sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-140...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645    sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-6...
# ...                                                                                               ...
# sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_run-1_...  sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_acq-V...
# sub-NDARVU683CTN_ses-HBNsiteRU_task-peer_run-1_...
# sub-NDARGX443CEU_ses-HBNsiteRU_task-rest_run-2_...  sub-NDARGX443CEU_ses-HBNsiteRU_task-rest_acq-V...
# sub-NDARGF367KVL_ses-HBNsiteRU_task-rest_run-1_...  sub-NDARGF367KVL_ses-HBNsiteRU_task-rest_acq-V...
# sub-NDARDF568GL5_ses-HBNsiteRU_task-peer_run-2_...  sub-NDARDF568GL5_ses-HBNsiteRU_task-peer_acq-V...
#
#                                                                   connectome: C-PAC: fmriprep-options
# subject_session
# sub-A00085406_ses-BAS1_acq-VARIANTObliquity
# sub-A00085406_ses-BAS1_task-rest_acq-1400
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645
# ...                                                                                               ...
# sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_run-1_...  sub-NDARLV387GP4_ses-HBNsiteRU_task-rest_run-1...
# sub-NDARVU683CTN_ses-HBNsiteRU_task-peer_run-1_...
# sub-NDARGX443CEU_ses-HBNsiteRU_task-rest_run-2_...
# sub-NDARGF367KVL_ses-HBNsiteRU_task-rest_run-1_...
# sub-NDARDF568GL5_ses-HBNsiteRU_task-peer_run-2_...
#
# [1987 rows x 5 columns]

# %%
# all phasediff fieldmap runs
df[(df['fieldmaps'] == 'phasediff')]
# Out:
#                                                    dataset  \
# subject_session
# sub-2207352563_ses-PNC1_acq-refaced                    PNC
# sub-2207352563_ses-PNC1_task-idemo_acq-VARIANTN...     PNC
# sub-2207352563_ses-PNC1_task-frac2back                 PNC
# sub-2412716526_ses-PNC1_acq-refaced                    PNC
# sub-2412716526_ses-PNC1_run-01                         PNC
# ...                                                    ...
# sub-NDARYM695TZY_ses-HBNsiteSI_task-rest               HBN
# sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-VA...     HBN
# sub-NDARTF833WXB_ses-HBNsiteSI_task-rest               HBN
# sub-NDARHB781DD8_ses-HBNsiteSI_task-rest               HBN
# sub-NDARFL411AT1_ses-HBNsiteSI_task-rest               HBN
#
#                                                                                                  path  \
# subject_session
# sub-2207352563_ses-PNC1_acq-refaced                 /ocean/projects/med220004p/shared/data_sandbox...
# sub-2207352563_ses-PNC1_task-idemo_acq-VARIANTN...  /ocean/projects/med220004p/shared/data_sandbox...
# sub-2207352563_ses-PNC1_task-frac2back              /ocean/projects/med220004p/shared/data_sandbox...
# sub-2412716526_ses-PNC1_acq-refaced                 /ocean/projects/med220004p/shared/data_sandbox...
# sub-2412716526_ses-PNC1_run-01                      /ocean/projects/med220004p/shared/data_sandbox...
# ...                                                                                               ...
# sub-NDARYM695TZY_ses-HBNsiteSI_task-rest            s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-VA...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARTF833WXB_ses-HBNsiteSI_task-rest            s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARHB781DD8_ses-HBNsiteSI_task-rest            s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARFL411AT1_ses-HBNsiteSI_task-rest            s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                     fieldmaps  \
# subject_session
# sub-2207352563_ses-PNC1_acq-refaced                 phasediff
# sub-2207352563_ses-PNC1_task-idemo_acq-VARIANTN...  phasediff
# sub-2207352563_ses-PNC1_task-frac2back              phasediff
# sub-2412716526_ses-PNC1_acq-refaced                 phasediff
# sub-2412716526_ses-PNC1_run-01                      phasediff
# ...                                                       ...
# sub-NDARYM695TZY_ses-HBNsiteSI_task-rest            phasediff
# sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-VA...  phasediff
# sub-NDARTF833WXB_ses-HBNsiteSI_task-rest            phasediff
# sub-NDARHB781DD8_ses-HBNsiteSI_task-rest            phasediff
# sub-NDARFL411AT1_ses-HBNsiteSI_task-rest            phasediff
#
#                                                                                  connectome: fMRIPrep  \
# subject_session
# sub-2207352563_ses-PNC1_acq-refaced
# sub-2207352563_ses-PNC1_task-idemo_acq-VARIANTN...  sub-2207352563_ses-PNC1_task-idemo_acq-VARIANT...
# sub-2207352563_ses-PNC1_task-frac2back              sub-2207352563_ses-PNC1_task-frac2back_space-M...
# sub-2412716526_ses-PNC1_acq-refaced
# sub-2412716526_ses-PNC1_run-01
# ...                                                                                               ...
# sub-NDARYM695TZY_ses-HBNsiteSI_task-rest
# sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-VA...  sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-V...
# sub-NDARTF833WXB_ses-HBNsiteSI_task-rest
# sub-NDARHB781DD8_ses-HBNsiteSI_task-rest            sub-NDARHB781DD8_ses-HBNsiteSI_task-rest_space...
# sub-NDARFL411AT1_ses-HBNsiteSI_task-rest            sub-NDARFL411AT1_ses-HBNsiteSI_task-rest_space...
#
#                                                                   connectome: C-PAC: fmriprep-options
# subject_session
# sub-2207352563_ses-PNC1_acq-refaced
# sub-2207352563_ses-PNC1_task-idemo_acq-VARIANTN...
# sub-2207352563_ses-PNC1_task-frac2back
# sub-2412716526_ses-PNC1_acq-refaced
# sub-2412716526_ses-PNC1_run-01
# ...                                                                                               ...
# sub-NDARYM695TZY_ses-HBNsiteSI_task-rest
# sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-VA...  sub-NDARJP133YL3_ses-HBNsiteSI_task-rest_acq-V...
# sub-NDARTF833WXB_ses-HBNsiteSI_task-rest
# sub-NDARHB781DD8_ses-HBNsiteSI_task-rest            sub-NDARHB781DD8_ses-HBNsiteSI_task-rest_space...
# sub-NDARFL411AT1_ses-HBNsiteSI_task-rest            sub-NDARFL411AT1_ses-HBNsiteSI_task-rest_space...
#
# [536 rows x 5 columns]

# %%
# all epi fieldmap runs
df[(df['fieldmaps']) == 'epi']
# Out:
#                                                    dataset  \
# subject_session
# sub-NDARNA354MGW_ses-HBNsiteCBIC_task-peer_run-3       HBN
# sub-NDARXF497LYF_ses-HBNsiteCBIC_task-movieTP          HBN
# sub-NDARYX806FL1_ses-HBNsiteRU_task-rest_run-2         HBN
# sub-NDARRL426AD5_ses-HBNsiteCBIC_task-rest_run-...     HBN
# sub-NDARFK610GY5_ses-HBNsiteRU_task-rest_run-1         HBN
# ...                                                    ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1         HBN
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1       HBN
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2         HBN
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...     HBN
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP            HBN
#
#                                                                                                  path  \
# subject_session
# sub-NDARNA354MGW_ses-HBNsiteCBIC_task-peer_run-3    s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARXF497LYF_ses-HBNsiteCBIC_task-movieTP       s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARYX806FL1_ses-HBNsiteRU_task-rest_run-2      s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARRL426AD5_ses-HBNsiteCBIC_task-rest_run-...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARFK610GY5_ses-HBNsiteRU_task-rest_run-1      s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# ...                                                                                               ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1      s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1    s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2      s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...  s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP         s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                    fieldmaps  \
# subject_session
# sub-NDARNA354MGW_ses-HBNsiteCBIC_task-peer_run-3         epi
# sub-NDARXF497LYF_ses-HBNsiteCBIC_task-movieTP            epi
# sub-NDARYX806FL1_ses-HBNsiteRU_task-rest_run-2           epi
# sub-NDARRL426AD5_ses-HBNsiteCBIC_task-rest_run-...       epi
# sub-NDARFK610GY5_ses-HBNsiteRU_task-rest_run-1           epi
# ...                                                      ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1           epi
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1         epi
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2           epi
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...       epi
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP              epi
#
#                                                                                  connectome: fMRIPrep  \
# subject_session
# sub-NDARNA354MGW_ses-HBNsiteCBIC_task-peer_run-3
# sub-NDARXF497LYF_ses-HBNsiteCBIC_task-movieTP
# sub-NDARYX806FL1_ses-HBNsiteRU_task-rest_run-2
# sub-NDARRL426AD5_ses-HBNsiteCBIC_task-rest_run-...
# sub-NDARFK610GY5_ses-HBNsiteRU_task-rest_run-1
# ...                                                                                               ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2      sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2...
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP
#
#                                                    connectome: C-PAC: fmriprep-options
# subject_session
# sub-NDARNA354MGW_ses-HBNsiteCBIC_task-peer_run-3
# sub-NDARXF497LYF_ses-HBNsiteCBIC_task-movieTP
# sub-NDARYX806FL1_ses-HBNsiteRU_task-rest_run-2
# sub-NDARRL426AD5_ses-HBNsiteCBIC_task-rest_run-...
# sub-NDARFK610GY5_ses-HBNsiteRU_task-rest_run-1
# ...                                                                                ...
# sub-NDARRW940BL6_ses-HBNsiteRU_task-rest_run-1
# sub-NDARPY458LTR_ses-HBNsiteCBIC_task-rest_run-1
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2
# sub-NDARPH567WUB_ses-HBNsiteCUNY_task-peer_run-...
# sub-NDARWN885MGD_ses-HBNsiteRU_task-movieTP
#
# [1645 rows x 5 columns]

# %%
# all runs with completed fMRIPrep connectome
df[(df['connectome: fMRIPrep'] != '')]
# Out:
#                                                   dataset  \
# subject_session
# sub-A00085406_ses-BAS1_task-rest_acq-1400             NKI
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400     NKI
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400       NKI
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645      NKI
# sub-A00085406_ses-BAS1_task-rest_acq-CAP              NKI
# ...                                                   ...
# sub-NDARGH592NZ2_ses-HBNsiteCBIC_task-peer_run-3      HBN
# sub-NDAREM731BYM_ses-HBNsiteRU_task-peer_run-3        HBN
# sub-NDARHW968ABB_ses-HBNsiteCBIC_task-peer_run-3      HBN
# sub-NDARHG321LLD_ses-HBNsiteRU_task-peer_run-1        HBN
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2        HBN
#
#                                                                                                 path  \
# subject_session
# sub-A00085406_ses-BAS1_task-rest_acq-1400          /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400  /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400    /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645   /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00085406_ses-BAS1_task-rest_acq-CAP           /ocean/projects/med220004p/shared/data_sandbox...
# ...                                                                                              ...
# sub-NDARGH592NZ2_ses-HBNsiteCBIC_task-peer_run-3   s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDAREM731BYM_ses-HBNsiteRU_task-peer_run-3     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARHW968ABB_ses-HBNsiteCBIC_task-peer_run-3   s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARHG321LLD_ses-HBNsiteRU_task-peer_run-1     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                   fieldmaps  \
# subject_session
# sub-A00085406_ses-BAS1_task-rest_acq-1400              None
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400      None
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400        None
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645       None
# sub-A00085406_ses-BAS1_task-rest_acq-CAP               None
# ...                                                     ...
# sub-NDARGH592NZ2_ses-HBNsiteCBIC_task-peer_run-3        epi
# sub-NDAREM731BYM_ses-HBNsiteRU_task-peer_run-3          epi
# sub-NDARHW968ABB_ses-HBNsiteCBIC_task-peer_run-3        epi
# sub-NDARHG321LLD_ses-HBNsiteRU_task-peer_run-1          epi
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2          epi
#
#                                                                                 connectome: fMRIPrep  \
# subject_session
# sub-A00085406_ses-BAS1_task-rest_acq-1400          sub-A00085406_ses-BAS1_task-rest_acq-1400_spac...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400  sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1...
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400    sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-140...
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645   sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-6...
# sub-A00085406_ses-BAS1_task-rest_acq-CAP           sub-A00085406_ses-BAS1_task-rest_acq-CAP_space...
# ...                                                                                              ...
# sub-NDARGH592NZ2_ses-HBNsiteCBIC_task-peer_run-3   sub-NDARGH592NZ2_ses-HBNsiteCBIC_task-peer_run...
# sub-NDAREM731BYM_ses-HBNsiteRU_task-peer_run-3     sub-NDAREM731BYM_ses-HBNsiteRU_task-peer_run-3...
# sub-NDARHW968ABB_ses-HBNsiteCBIC_task-peer_run-3   sub-NDARHW968ABB_ses-HBNsiteCBIC_task-peer_run...
# sub-NDARHG321LLD_ses-HBNsiteRU_task-peer_run-1     sub-NDARHG321LLD_ses-HBNsiteRU_task-peer_run-1...
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2     sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2...
#
#                                                   connectome: C-PAC: fmriprep-options
# subject_session
# sub-A00085406_ses-BAS1_task-rest_acq-1400
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-1400
# sub-A00085406_ses-BAS1_task-BREATHHOLD_acq-1400
# sub-A00085406_ses-BAS1_task-CHECKERBOARD_acq-645
# sub-A00085406_ses-BAS1_task-rest_acq-CAP
# ...                                                                               ...
# sub-NDARGH592NZ2_ses-HBNsiteCBIC_task-peer_run-3
# sub-NDAREM731BYM_ses-HBNsiteRU_task-peer_run-3
# sub-NDARHW968ABB_ses-HBNsiteCBIC_task-peer_run-3
# sub-NDARHG321LLD_ses-HBNsiteRU_task-peer_run-1
# sub-NDARDN489EXJ_ses-HBNsiteRU_task-rest_run-2
#
# [2546 rows x 5 columns]

# %%
# all runs with completed C-PAC:fmriprep-options connectome
df[(df['connectome: C-PAC: fmriprep-options'] != '')]
# Out:
#                                                   dataset  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP              NKI
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645      NKI
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400       NKI
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400     NKI
# sub-A00037229_ses-FLU1_task-rest_acq-1400             NKI
# ...                                                   ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1        HBN
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1      HBN
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP           HBN
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1        HBN
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3        HBN
#
#                                                                                                 path  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP           /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645   /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400    /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400  /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-rest_acq-1400          /ocean/projects/med220004p/shared/data_sandbox...
# ...                                                                                              ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1   s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP        s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                   fieldmaps  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP               None
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645       None
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400        None
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400      None
# sub-A00037229_ses-FLU1_task-rest_acq-1400              None
# ...                                                     ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1          epi
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1        epi
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP             epi
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1          epi
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3          epi
#
#                                                                                 connectome: fMRIPrep  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP           sub-A00037229_ses-FLU1_task-rest_acq-CAP_space...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645   sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-6...
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400    sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-140...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400  sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1...
# sub-A00037229_ses-FLU1_task-rest_acq-1400          sub-A00037229_ses-FLU1_task-rest_acq-1400_spac...
# ...                                                                                              ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1     sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1...
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1   sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run...
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP        sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP_sp...
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1     sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1...
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3     sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3...
#
#                                                                  connectome: C-PAC: fmriprep-options
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP           sub-A00037229_ses-FLU1_task-rest_acq-CAP_space...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645   sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-6...
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400    sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-140...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400  sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1...
# sub-A00037229_ses-FLU1_task-rest_acq-1400          sub-A00037229_ses-FLU1_task-rest_acq-1400_spac...
# ...                                                                                              ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1     sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1...
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1   sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run...
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP        sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP_sp...
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1     sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1...
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3     sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3...
#
# [386 rows x 5 columns]

# %%
# all runs with both completed fMRIPrep connectome and completed C-PAC:fmriprep-options connectome
df[(df['connectome: fMRIPrep'] != '') & (df['connectome: C-PAC: fmriprep-options'] != '')]
# Out:
#                                                   dataset  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP              NKI
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645      NKI
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400       NKI
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400     NKI
# sub-A00037229_ses-FLU1_task-rest_acq-1400             NKI
# ...                                                   ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1        HBN
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1      HBN
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP           HBN
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1        HBN
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3        HBN
#
#                                                                                                 path  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP           /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645   /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400    /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400  /ocean/projects/med220004p/shared/data_sandbox...
# sub-A00037229_ses-FLU1_task-rest_acq-1400          /ocean/projects/med220004p/shared/data_sandbox...
# ...                                                                                              ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1   s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP        s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3     s3://fcp-indi/data/Projects/HBN/BIDS_datalad/s...
#
#                                                   fieldmaps  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP               None
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645       None
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400        None
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400      None
# sub-A00037229_ses-FLU1_task-rest_acq-1400              None
# ...                                                     ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1          epi
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1        epi
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP             epi
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1          epi
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3          epi
#
#                                                                                 connectome: fMRIPrep  \
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP           sub-A00037229_ses-FLU1_task-rest_acq-CAP_space...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645   sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-6...
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400    sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-140...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400  sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1...
# sub-A00037229_ses-FLU1_task-rest_acq-1400          sub-A00037229_ses-FLU1_task-rest_acq-1400_spac...
# ...                                                                                              ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1     sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1...
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1   sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run...
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP        sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP_sp...
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1     sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1...
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3     sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3...
#
#                                                                  connectome: C-PAC: fmriprep-options
# subject_session
# sub-A00037229_ses-FLU1_task-rest_acq-CAP           sub-A00037229_ses-FLU1_task-rest_acq-CAP_space...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-645   sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-6...
# sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-1400    sub-A00037229_ses-FLU1_task-BREATHHOLD_acq-140...
# sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1400  sub-A00037229_ses-FLU1_task-CHECKERBOARD_acq-1...
# sub-A00037229_ses-FLU1_task-rest_acq-1400          sub-A00037229_ses-FLU1_task-rest_acq-1400_spac...
# ...                                                                                              ...
# sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1     sub-NDARAX283MAK_ses-HBNsiteRU_task-rest_run-1...
# sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run-1   sub-NDAREY897LB1_ses-HBNsiteCBIC_task-peer_run...
# sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP        sub-NDARFG568PXZ_ses-HBNsiteRU_task-movieTP_sp...
# sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1     sub-NDARCG073GZ6_ses-HBNsiteRU_task-peer_run-1...
# sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3     sub-NDARTH433TE0_ses-HBNsiteRU_task-peer_run-3...
#
# [367 rows x 5 columns]
